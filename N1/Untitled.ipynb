# %%
num1 = []
num2 = []
num3 = []
num = [
   1,4,4,2,4,4,3,4,1,4,1,2,1,2,1,1,4,1,3,2,4,3,1,1,2,2,2,2,1,2,4,2,4,2,2,1,1,1,1,1,2,3,3,1,4,2,3,1,2,4,2,1,2,4,2,1,4,4,1,2,3,2,1,1,1,2,4,2,2,1,3,2,2,4,1,2,4,2,1,1,1,3,1,3,3,3,1,1,2,2
]
for i in range(len(num)):
    if i % 3 == 0:
        num1.append(num[i])
    elif i % 3 == 1:
        num2.append(num[i])
    else:
        num3.append(num[i])
print(len(num1))
# Out:
# 30

# %%
final = ""
with open('12N1.txt', encoding="utf-8") as f:
    line = f.readlines()
for index in range(len(line)):
    string = ""
    cell = (line[index].replace("\n", "")).split(",")
    cell[-1] = cell[num3[index]+1]  ############################
    for cells in cell:
        string += cells.replace(" ", "")
        string += ","
    final += string[:-1] + "\n"
print(final)
# Out:
# 378,やっと帰れるかと__________、急ぎの仕事が入ってしまった。,思うにもまして,思わんばかりに,思ったが最後,思いきや,思いきや
# 381,彼は熱があるので今日は欠席する__________です。,という,こと,もの,とのこと,とのこと
# 384,娘は作文を__________消し、なかなかできあがらないようだ。,書いては,書いたり,書くし,書きがてら,書いては
# 387,A『何ですか、この成績は。ちゃんと勉強しているんですか。』/B『__________つもりですが⋯。』,する,している,しない,していない,している
# 390,お客さん__________、希望に添えないとは言いにくかった。,の手前,のそばから,をよそに,をものともせず,の手前
# 393,A『素敵なヴァイオリンね。ちょっと弾いて__________。』/B『今、練習中だから、また今度ね。』,みせて,みるね,聞こえて,聞かれて,みせて
# 396,気象庁の3ヶ月予報によると、関東地方の気温は平年__________だそうです。,ずくめ,めく,まみれ,なみ,なみ
# 399,何度も落ちていますが、今度__________今度は面接試験に受かってみせます。,という,こそ,といい,にまして,という
# 402,A『もうこの店には二度と来ないよ。』/B『そうだね、高いのにまずくて、おまけに店員が無愛想__________。』,始末だ,ときている,に難くない,でなくてなんだろう,ときている
# 405,就職活動の時期__________、リクルートスーツの若い人たちの姿が目立つようになった。,とばかりに,とみえて,ともなしに,とはいえ,とみえて
# 408,今回の火山の噴火は、先の大地震の影響によるもの__________。,にはあたらない,といったらない,を禁じ得ない,とみられている,とみられている
# 411,自分の手に負えない__________、すぐ誰かを頼ろうとするのはよくない。,とみると,とみえて,ときて,と思いきや,とみると
# 414,この宝石は本物__________偽物__________わからない。,とも/とも,だの/だの,だに/だに,なり/なり,とも/とも
# ...
